# %%
import requests
import csv
import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

class Crypto_exchg:
    def __init__(self):
        self.exchanges = []
        self.vol24 = []
        self.assets = []
        self.filename = "./exch_asset"+(str(datetime.datetime.now()).replace(" ",""))+'.csv'
        self.filename_ast = "./asset_det"+(str(datetime.datetime.now()).replace(" ",""))+'.csv'

    def exchange_market(self):

        ## Get the exchanges data
        url = "https://www.cryptingup.com/api/exchanges"
        exchg = requests.get(url)
        exchg_list = dict(exchg.json())
        exchg_ig = exchg_list['exchanges']
        exchg_final_list = []
        asst_list = []
        
        for i in exchg_ig:
            self.exchanges.append(i['id'])
        ## Get the Market data with exchane id
            url = "https://www.cryptingup.com/api/exchanges/{}/markets".format(i['id'])
            mrkt = requests.get(url)
            mrkt_list = dict(mrkt.json())
            mrkt_ig = mrkt_list['markets']

            for j in mrkt_ig:
                asst_exchange = j['exchange_id']
                asst_name = j['base_asset']
                asst_price = j['price']
                asst_vol_24h = j['volume_24h']
                asst_symbol = j['symbol']
                asst_change_24h = j['change_24h']
                asst_list.append([asst_exchange,asst_symbol,asst_name,asst_price,asst_vol_24h,asst_change_24h])
        fields = ['Exchg','symbol','asset','price','vol24','change24']
        with open(self.filename, 'w') as csvfile:
            csvwriter = csv.writer(csvfile)
            csvwriter.writerow(fields)
            csvwriter.writerows(asst_list)
            csvfile.close()
                
    def asset_details(self):

        url = "https://www.cryptingup.com/api/assets"
        asset_det = requests.get(url)
        asset_det_list = dict(asset_det.json())
        asset_det_ig = asset_det_list['assets']
        assetdet_final_list = []
        asstdet_list = []
        #print(asset_det_ig)
        for as_det_val in asset_det_ig:
            self.assets.append(as_det_val['id'])

        
    ##Get the asset details for asset
            url = "https://www.cryptingup.com/api/assets/{}".format(as_det_val['id'])
            as_det = requests.get(url)
            as_det_list = dict(as_det.json())
            as_det_ig = as_det_list['asset']
            asst_det_id = as_det_ig['id']
            asst_det_name = as_det_ig['name']
            asst_det_price = as_det_ig['price']
            asst_det_v24h = as_det_ig['volume_24h']
            asst_det_ch1h = as_det_ig['change_1h']
            asst_det_ch24h = as_det_ig['change_24h']
            asst_det_ch7d = as_det_ig['change_7d']
            asstdet_list.append([asst_det_id,asst_det_name,asst_det_price,asst_det_v24h,asst_det_ch1h,asst_det_ch24h,\
                             asst_det_ch7d])

        fields = ['astid','name','price','vol24','chg1h','chg24h','chg7d']
        with open(self.filename_ast, 'w') as csvfile:
            csvwriter = csv.writer(csvfile)
            csvwriter.writerow(fields)
            csvwriter.writerows(asstdet_list)
            csvfile.close()

    def plot_values(self):

        stock_df = pd.read_csv(self.filename)
        asset_df = pd.read_csv(self.filename_ast)
        
        ### Displays details of the given asset
        inp_asst = (input(" Select an asset to view current price [BTC,ETH,SOL,DOGE,GALA,XLM,ATOM,CLV] : ")).upper()
        asset_spec = asset_df[asset_df['astid'] == inp_asst]
        display(asset_spec)
        
        # Analysis on Exchange Market
        print(" TOP ASSETS BASED ON PRICE ACROSS ALL EXCHANGES")
        stock_val = stock_df.sort_values(by = 'price', ascending = False)[:10]
        display(stock_val)
        print(" \n")
        
        
        print("AVERAGE PRICE OF ASSETS IN EACH EXCHANGE")
        avrg_price = stock_df.groupby(by = 'Exchg')['price'].mean()
        display(avrg_price)
        print(" \n")
        
        for exchg in self.exchanges:
            print(f'TOP 5 ASSETS OF {exchg} BY PRICE')
            coin_df = stock_df[stock_df['Exchg'].isin([exchg])]
            sort_coin = coin_df.sort_values(by = 'price', ascending = False)[:5]
            display(sort_coin)
            print(f'TOP 5 ASSETS OF {exchg} BY 24H VOLUME')
            sort_coin1 = coin_df.sort_values(by = 'vol24', ascending = False)[:5]
            display(sort_coin1)
            print(" \n")
      
        ## Plotting
        plt.figure(figsize=(16,19))
        ax1 = plt.subplot(3,1,1)
        ax1.set_title("Volume change in 24H of Exchanges")
        ax1.plot(stock_df['Exchg'],stock_df['vol24'])

       
        ax2 = plt.subplot(3,1,2)
        ax2.set_title("Price Range vs Exchanges")
        ax2.bar(stock_df['Exchg'],stock_df['price'],color = 'orange')  
        
        ax3 = plt.subplot(3,1,3)
        ax2.set_title("asst")
        ax2.bar(stock_df['Exchg'],stock_df['price'],color = 'orange')
    
my_crypto = Crypto_exchg()
my_crypto.exchange_market()
my_crypto.asset_details()
my_crypto.plot_values()
# Out:
#  TOP ASSETS BASED ON PRICE ACROSS ALL EXCHANGES
#            Exchg    symbol asset         price         vol24  change24
# 442     BITFINEX   BTC-XCH   BTC  9.654842e+06  9.654842e+05 -1.824571
# 331       KRAKEN  XBT-USDC   XBT  4.842546e+04  4.188843e+06  1.724150
# 421     BITFINEX   BTC-JPY   BTC  4.834337e+04  5.527357e+06  1.272672
# 315       KRAKEN  XBT-USDT   XBT  4.833418e+04  9.522141e+06  1.517542
# 400     BITFINEX   BTC-USD   BTC  4.833200e+04  1.186687e+08  1.280359
# 363       KRAKEN   XBT-CAD   XBT  4.833161e+04  1.487356e+06  1.759682
# 301       KRAKEN   XBT-USD   XBT  4.832915e+04  8.148970e+07  1.591374
# 231     COINBASE  BTC-USDT   BTC  4.832792e+04  2.149168e+07  1.395359
# 202     COINBASE   BTC-USD   BTC  4.832700e+04  4.143870e+08  1.464375
# 601      BITTREX   BTC-USD   BTC  4.832415e+04  7.382570e+06  1.575282
# 602      BITTREX  BTC-USDT   BTC  4.832402e+04  4.937513e+06  1.562164
# 59       BINANCE   BTC-EUR   BTC  4.832332e+04  6.742161e+07  1.724554
# 502     POLONIEX  BTC-USDT   BTC  4.832100e+04  2.205821e+07  1.524404
# 101  HUOBIGLOBAL  BTC-USDT   BTC  4.832070e+04  5.309697e+08 -0.216396
# 0        BINANCE  BTC-USDT   BTC  4.832029e+04  1.644407e+09  1.532824
# 7        BINANCE  BTC-BUSD   BTC  4.831922e+04  4.395809e+08  1.529217
# 506     POLONIEX  BTC-USDC   BTC  4.831917e+04  4.376944e+06  1.565059
# 220     COINBASE  BTC-USDC   BTC  4.831835e+04  3.287303e+07  1.392600
# 380       KRAKEN   XBT-CHF   XBT  4.831372e+04  8.909825e+05  1.983930
# 403     BITFINEX   BTC-UST   BTC  4.831210e+04  4.312545e+07  1.291486
# 63       BINANCE  BTC-USDC   BTC  4.830878e+04  5.787122e+07  1.538403
# 474     BITFINEX   BTC-EUT   BTC  4.830235e+04  3.955103e+05  1.533462
# 340       KRAKEN   XBT-GBP   XBT  4.827258e+04  2.654537e+06  1.687387
# 422     BITFINEX   BTC-GBP   BTC  4.826757e+04  5.050000e+06  1.573780
# 219     COINBASE   BTC-GBP   BTC  4.826119e+04  3.302349e+07  1.481157
# 212     COINBASE   BTC-EUR   BTC  4.823158e+04  4.429725e+07  1.456322
# 616      BITTREX   BTC-EUR   BTC  4.823119e+04  1.691366e+06  1.538387
# 303       KRAKEN   XBT-EUR   XBT  4.822799e+04  5.997684e+07  1.649460
# 415     BITFINEX   BTC-EUR   BTC  4.822138e+04  7.245676e+06  1.337431
# 281     COINBASE   YFI-USD   YFI  3.391024e+04  5.140342e+06  0.183925
#
#
# AVERAGE PRICE OF ASSETS IN EACH EXCHANGE
# Exchg
# BINANCE          2151.242349
# BITFINEX       100377.523198
# BITTREX          1618.074923
# COINBASE         3041.013023
# HUOBIGLOBAL       595.439130
# KRAKEN           3653.945532
# POLONIEX         1630.297779
# Name: price, dtype: float64
#
#
# TOP 5 ASSETS OF BINANCE BY PRICE
#       Exchg    symbol asset         price         vol24  change24
# 59  BINANCE   BTC-EUR   BTC  48323.321423  6.742161e+07  1.724554
# 0   BINANCE  BTC-USDT   BTC  48320.292160  1.644407e+09  1.532824
# 7   BINANCE  BTC-BUSD   BTC  48319.217899  4.395809e+08  1.529217
# 63  BINANCE  BTC-USDC   BTC  48308.776512  5.787122e+07  1.538403
# 10  BINANCE   ETH-BTC   ETH   3467.021034  3.251492e+08 -1.329765
# TOP 5 ASSETS OF BINANCE BY 24H VOLUME
#      Exchg     symbol asset         price         vol24   change24
# 0  BINANCE   BTC-USDT   BTC  48320.292160  1.644407e+09   1.532824
# 1  BINANCE   SOL-USDT   SOL    163.465011  1.298223e+09  13.410826
# 2  BINANCE   ETH-USDT   ETH   3465.493235  1.166497e+09   0.182892
# 3  BINANCE  AVAX-USDT  AVAX     70.652293  8.352433e+08   7.823233
# 4  BINANCE  GALA-USDT  GALA      0.125271  7.346356e+08  41.370358
#
#
# TOP 5 ASSETS OF HUOBIGLOBAL BY PRICE
#            Exchg    symbol asset         price         vol24  change24
# 101  HUOBIGLOBAL  BTC-USDT   BTC  48320.702261  5.309697e+08 -0.216396
# 121  HUOBIGLOBAL   ETH-BTC   ETH   3467.166066  3.986059e+07 -0.071757
# 100  HUOBIGLOBAL  ETH-USDT   ETH   3465.873328  6.045805e+08 -0.276432
# 136  HUOBIGLOBAL  BCH-USDT   BCH    628.838918  2.135462e+07 -0.216649
# 160  HUOBIGLOBAL  KSM-USDT   KSM    410.057368  8.815226e+06 -0.092850
# TOP 5 ASSETS OF HUOBIGLOBAL BY 24H VOLUME
#            Exchg    symbol asset         price         vol24  change24
# 100  HUOBIGLOBAL  ETH-USDT   ETH   3465.873328  6.045805e+08 -0.276432
# 101  HUOBIGLOBAL  BTC-USDT   BTC  48320.702261  5.309697e+08 -0.216396
# 102  HUOBIGLOBAL  FIL-USDT   FIL     84.409761  2.294640e+08 -0.832923
# 103  HUOBIGLOBAL  SOL-USDT   SOL    163.411197  1.602588e+08 -0.174024
# 104  HUOBIGLOBAL  NFT-USDT   NFT      0.000004  1.578822e+08 -1.033382
#
#
# TOP 5 ASSETS OF COINBASE BY PRICE
#         Exchg    symbol asset         price         vol24  change24
# 231  COINBASE  BTC-USDT   BTC  48327.924028  2.149168e+07  1.395359
# 202  COINBASE   BTC-USD   BTC  48326.995000  4.143870e+08  1.464375
# 220  COINBASE  BTC-USDC   BTC  48318.345708  3.287303e+07  1.392600
# 219  COINBASE   BTC-GBP   BTC  48261.186106  3.302349e+07  1.481157
# 212  COINBASE   BTC-EUR   BTC  48231.579254  4.429725e+07  1.456322
# TOP 5 ASSETS OF COINBASE BY 24H VOLUME
#         Exchg    symbol asset       price         vol24   change24
# 200  COINBASE   SOL-USD   SOL    163.5545  6.282157e+08  12.957463
# 201  COINBASE   ETH-USD   ETH   3465.2800  5.164138e+08   0.191404
# 202  COINBASE   BTC-USD   BTC  48326.9950  4.143870e+08   1.464375
# 203  COINBASE   ADA-USD   ADA      2.3884  1.381554e+08   0.302369
# 204  COINBASE  ATOM-USD  ATOM     39.1870  1.146303e+08  14.958343
#
#
# TOP 5 ASSETS OF KRAKEN BY PRICE
#       Exchg    symbol asset         price         vol24  change24
# 331  KRAKEN  XBT-USDC   XBT  48425.456709  4.188843e+06  1.724150
# 315  KRAKEN  XBT-USDT   XBT  48334.180560  9.522141e+06  1.517542
# 363  KRAKEN   XBT-CAD   XBT  48331.605360  1.487356e+06  1.759682
# 301  KRAKEN   XBT-USD   XBT  48329.150000  8.148970e+07  1.591374
# 380  KRAKEN   XBT-CHF   XBT  48313.715753  8.909825e+05  1.983930
# TOP 5 ASSETS OF KRAKEN BY 24H VOLUME
#       Exchg    symbol asset         price         vol24   change24
# 300  KRAKEN   ETH-USD   ETH   3465.560000  1.101423e+08   0.222971
# 301  KRAKEN   XBT-USD   XBT  48329.150000  8.148970e+07   1.591374
# 302  KRAKEN  USDT-USD  USDT      1.000150  6.106997e+07   0.005000
# 303  KRAKEN   XBT-EUR   XBT  48227.987716  5.997684e+07   1.649460
# 304  KRAKEN  ATOM-USD  ATOM     39.170550  3.436617e+07  15.305849
#
#
# TOP 5 ASSETS OF BITFINEX BY PRICE
#         Exchg   symbol asset         price         vol24  change24
# 442  BITFINEX  BTC-XCH   BTC  9.654842e+06  9.654842e+05 -1.824571
# 421  BITFINEX  BTC-JPY   BTC  4.834337e+04  5.527357e+06  1.272672
# 400  BITFINEX  BTC-USD   BTC  4.833200e+04  1.186687e+08  1.280359
# 403  BITFINEX  BTC-UST   BTC  4.831210e+04  4.312545e+07  1.291486
# 474  BITFINEX  BTC-EUT   BTC  4.830235e+04  3.955103e+05  1.533462
# TOP 5 ASSETS OF BITFINEX BY 24H VOLUME
#         Exchg   symbol asset         price         vol24   change24
# 400  BITFINEX  BTC-USD   BTC  48332.000000  1.186687e+08   1.280359
# 401  BITFINEX  SOL-USD   SOL    163.670000  6.401078e+07  12.310437
# 402  BITFINEX  ETH-USD   ETH   3465.450000  5.395035e+07  -0.154143
# 403  BITFINEX  BTC-UST   BTC  48312.099347  4.312545e+07   1.291486
# 404  BITFINEX  ETH-BTC   ETH   3466.827657  3.897163e+07  -1.405807
#
#
# TOP 5 ASSETS OF POLONIEX BY PRICE
#         Exchg     symbol asset         price         vol24  change24
# 502  POLONIEX   BTC-USDT   BTC  48321.001088  2.205821e+07  1.524404
# 506  POLONIEX   BTC-USDC   BTC  48319.174849  4.376944e+06  1.565059
# 576  POLONIEX   YFI-USDT   YFI  33901.127659  4.380058e+04  0.361711
# 549  POLONIEX  BULL-USDT  BULL   9616.681474  9.382720e+04  5.896736
# 597  POLONIEX    ETH-TRX   ETH   3469.725111  2.160280e+04  1.132513
# TOP 5 ASSETS OF POLONIEX BY 24H VOLUME
#         Exchg     symbol asset         price         vol24   change24
# 500  POLONIEX   TRX-USDT   TRX      0.105881  2.977033e+07  -0.799838
# 501  POLONIEX    ETH-BTC   ETH   3467.032153  2.658453e+07  -1.356864
# 502  POLONIEX   BTC-USDT   BTC  48321.001088  2.205821e+07   1.524404
# 503  POLONIEX   ETH-USDT   ETH   3465.519963  1.578010e+07   0.178134
# 504  POLONIEX  GALA-USDT  GALA      0.125341  6.010302e+06  39.826432
#
#
# TOP 5 ASSETS OF BITTREX BY PRICE
#        Exchg    symbol asset         price         vol24  change24
# 601  BITTREX   BTC-USD   BTC  48324.146000  7.382570e+06  1.575282
# 602  BITTREX  BTC-USDT   BTC  48324.015781  4.937513e+06  1.562164
# 616  BITTREX   BTC-EUR   BTC  48231.194948  1.691366e+06  1.538387
# 603  BITTREX   ETH-BTC   ETH   3467.161232  4.077033e+06 -1.399520
# 606  BITTREX  ETH-USDT   ETH   3465.460963  2.873261e+06  0.074119
# TOP 5 ASSETS OF BITTREX BY 24H VOLUME
#        Exchg      symbol  asset         price         vol24  change24
# 600  BITTREX  JASMY-USDT  JASMY      0.023261  7.979597e+06  0.366854
# 601  BITTREX     BTC-USD    BTC  48324.146000  7.382570e+06  1.575282
# 602  BITTREX    BTC-USDT    BTC  48324.015781  4.937513e+06  1.562164
# 603  BITTREX     ETH-BTC    ETH   3467.161232  4.077033e+06 -1.399520
# 604  BITTREX     ETH-USD    ETH   3465.244000  3.983745e+06  0.069105
#  Select an asset to view current price [BTC,ETH,SOL,DOGE,GALA,XLM,ATOM,CLV] :  atom
#   astid    name      price         vol24     chg1h     chg24h      chg7d
# 9  ATOM  Cosmos  39.185909  6.867641e+08  0.067408  14.382243  41.440267
