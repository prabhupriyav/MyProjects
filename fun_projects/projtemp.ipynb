# %%
import requests
import csv
import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

class crypto_exchg:
    def __init__(self):
        self.exchanges = []
        self.vol24 = []
        self.assets = []
        self.filename = "./exch_asset"+(str(datetime.datetime.now()).replace(" ",""))+'.csv'

    ## Gets Crypto data from API, select items, write to .csv file    
    def api_calls(self):
        url = "https://www.cryptingup.com/api/exchanges"
        exchg = requests.get(url)
        exchg_list = dict(exchg.json())
        exchg_ig = exchg_list['exchanges']
        exchg_final_list = []
        asst_list = []
        for i in exchg_ig:
            self.exchanges.append(i['id'])
            self.vol24.append(i['volume_24h'])
            url = "https://www.cryptingup.com/api/exchanges/{}/markets".format(i['id'])
            mrkt = requests.get(url)
            mrkt_list = dict(mrkt.json())
            mrkt_ig = mrkt_list['markets']

            for j in mrkt_ig:
                asst_exchange = j['exchange_id']
                asst_name = j['base_asset']
                asst_price = j['price']
                asst_vol_24h = j['volume_24h']
                asst_symbol = j['symbol']
                asst_change_24h = j['change_24h']
                asst_list.append([asst_exchange,asst_symbol,asst_name,asst_price,asst_vol_24h,asst_change_24h])

        fields = ['Exchg','symbol','asset','price','vol24','change24']
        with open(self.filename, 'w') as csvfile:
            csvwriter = csv.writer(csvfile)
            csvwriter.writerow(fields)
            csvwriter.writerows(asst_list)
            csvfile.close()

    ## Display Output and Plotting Graphs using Panda and Matplotlib       
    def plot_values(self):
        stock_df = pd.read_csv(self.filename)
        print(" TOP ASSETS BASED ON PRICE ACROSS ALL EXCHANGES")
        stock_val = stock_df.sort_values(by = 'price', ascending = False)[:30]
        display(stock_val)
        
        print(" \n")
        print("AVERAGE PRICE OF ASSETS IN EACH EXCHANGE")
        avrg_price = stock_df.groupby(by = 'Exchg')['price'].mean()
        display(avrg_price)
        print(" \n")
        
        for exchg in self.exchanges:
            print(f'TOP 5 ASSETS OF {exchg} BY PRICE')
            coin_df = stock_df[stock_df['Exchg'].isin([exchg])]
            sort_coin = coin_df.sort_values(by = 'price', ascending = False)[:5]
            display(sort_coin)
            print(f'TOP 5 ASSETS OF {exchg} BY 24H VOLUME')
            sort_coin1 = coin_df.sort_values(by = 'vol24', ascending = False)[:5]
            display(sort_coin1)
            print(" \n")


        plt.figure(figsize=(16,19))
        
        ax1 = plt.subplot(2,1,1)
        ax1.set_title("Volume change in 24H of Exchanges")
        ax1.plot(stock_df['Exchg'],stock_df['vol24'])

       
        ax2 = plt.subplot(2,1,2)
        ax2.set_title("Price Range vs Exchanges")
        ax2.bar(stock_df['Exchg'],stock_df['price'],color = 'orange')        
    
my_crypto = crypto_exchg()
my_crypto.api_calls()
my_crypto.plot_values()
# Out:
#  TOP ASSETS BASED ON PRICE ACROSS ALL EXCHANGES
#            Exchg    symbol asset         price         vol24  change24
# 460     BITFINEX   BTC-XCH   BTC  9.815509e+06  9.815509e+05  0.293135
# 400     BITFINEX   BTC-USD   BTC  4.875550e+04  1.393155e+08  1.739285
# 220     COINBASE  BTC-USDC   BTC  4.874963e+04  3.722819e+07  2.110634
# 301       KRAKEN   XBT-USD   XBT  4.872455e+04  9.971976e+07  1.563223
# 347       KRAKEN  XBT-USDC   XBT  4.872108e+04  2.580070e+06  1.632184
# 234     COINBASE  BTC-USDT   BTC  4.871721e+04  2.221595e+07  2.081364
# 602      BITTREX  BTC-USDT   BTC  4.871635e+04  6.032368e+06  1.525274
# 601      BITTREX   BTC-USD   BTC  4.871557e+04  7.858847e+06  1.544007
# 506     POLONIEX  BTC-USDC   BTC  4.871334e+04  3.996062e+06  1.544915
# 202     COINBASE   BTC-USD   BTC  4.870964e+04  4.776405e+08  2.046711
# 424     BITFINEX   BTC-JPY   BTC  4.870890e+04  6.734283e+06  1.754629
# 502     POLONIEX  BTC-USDT   BTC  4.870530e+04  2.553277e+07  1.526363
# 101  HUOBIGLOBAL  BTC-USDT   BTC  4.870433e+04  5.856189e+08  2.479682
# 0        BINANCE  BTC-USDT   BTC  4.870235e+04  1.887911e+09  1.527086
# 63       BINANCE  BTC-USDC   BTC  4.870229e+04  6.575403e+07  1.497174
# 320       KRAKEN  XBT-USDT   XBT  4.870207e+04  1.015273e+07  1.525771
# 7        BINANCE  BTC-BUSD   BTC  4.870203e+04  4.751993e+08  1.494374
# 421     BITFINEX   BTC-GBP   BTC  4.869359e+04  8.065195e+06  1.989020
# 339       KRAKEN   XBT-GBP   XBT  4.867472e+04  3.436115e+06  2.021636
# 55       BINANCE   BTC-EUR   BTC  4.866075e+04  7.607645e+07  1.877034
# 223     COINBASE   BTC-GBP   BTC  4.865899e+04  3.489143e+07  2.434739
# 302       KRAKEN   XBT-EUR   XBT  4.865642e+04  8.971207e+07  2.089683
# 361       KRAKEN   XBT-CAD   XBT  4.865516e+04  1.837956e+06  2.366768
# 404     BITFINEX   BTC-UST   BTC  4.864904e+04  4.511151e+07  1.723454
# 288     COINBASE  WBTC-BTC  WBTC  4.863970e+04  5.669602e+06  0.004999
# 613      BITTREX   BTC-EUR   BTC  4.863078e+04  1.935772e+06  2.082766
# 416     BITFINEX   BTC-EUR   BTC  4.863040e+04  1.044720e+07  2.233778
# 214     COINBASE   BTC-EUR   BTC  4.862685e+04  5.374637e+07  2.563669
# 383       KRAKEN   XBT-CHF   XBT  4.857861e+04  1.094392e+06  1.918807
# 439     BITFINEX   YFI-USD   YFI  3.405150e+04  2.201468e+06 -1.394318
#
#
# AVERAGE PRICE OF ASSETS IN EACH EXCHANGE
# Exchg
# BINANCE          2168.573950
# BITFINEX       101562.281738
# BITTREX          1622.683873
# COINBASE         3550.913668
# HUOBIGLOBAL       603.254586
# KRAKEN           3679.316459
# POLONIEX         1644.444304
# Name: price, dtype: float64
#
#
# TOP 5 ASSETS OF BINANCE BY PRICE
#       Exchg    symbol asset         price         vol24  change24
# 0   BINANCE  BTC-USDT   BTC  48702.347322  1.887911e+09  1.527086
# 63  BINANCE  BTC-USDC   BTC  48702.291733  6.575403e+07  1.497174
# 7   BINANCE  BTC-BUSD   BTC  48702.032119  4.751993e+08  1.494374
# 55  BINANCE   BTC-EUR   BTC  48660.751365  7.607645e+07  1.877034
# 88  BINANCE  ETH-USDC   ETH   3515.564937  4.271880e+07 -0.636268
# TOP 5 ASSETS OF BINANCE BY 24H VOLUME
#      Exchg     symbol asset         price         vol24   change24
# 0  BINANCE   BTC-USDT   BTC  48702.347322  1.887911e+09   1.527086
# 1  BINANCE   SOL-USDT   SOL    158.919104  1.485289e+09  10.297078
# 2  BINANCE   ETH-USDT   ETH   3515.026958  1.440853e+09  -0.577771
# 3  BINANCE  AVAX-USDT  AVAX     72.551439  9.501976e+08  13.689077
# 4  BINANCE  BUSD-USDT  BUSD      1.000039  8.260819e+08   0.015003
#
#
# TOP 5 ASSETS OF HUOBIGLOBAL BY PRICE
#            Exchg    symbol asset         price         vol24  change24
# 101  HUOBIGLOBAL  BTC-USDT   BTC  48704.327498  5.856189e+08  2.479682
# 121  HUOBIGLOBAL   ETH-BTC   ETH   3515.293504  5.171137e+07 -0.625843
# 100  HUOBIGLOBAL  ETH-USDT   ETH   3514.906947  7.761091e+08  1.859033
# 129  HUOBIGLOBAL  BCH-USDT   BCH    635.571407  3.309318e+07  1.338659
# 164  HUOBIGLOBAL  KSM-USDT   KSM    414.389777  1.040542e+07  4.295399
# TOP 5 ASSETS OF HUOBIGLOBAL BY 24H VOLUME
#            Exchg    symbol asset         price         vol24  change24
# 100  HUOBIGLOBAL  ETH-USDT   ETH   3514.906947  7.761091e+08  1.859033
# 101  HUOBIGLOBAL  BTC-USDT   BTC  48704.327498  5.856189e+08  2.479682
# 102  HUOBIGLOBAL  FIL-USDT   FIL     85.568444  2.651746e+08  4.056978
# 103  HUOBIGLOBAL  NFT-USDT   NFT      0.000004  1.844895e+08 -0.521064
# 104  HUOBIGLOBAL  SOL-USDT   SOL    158.911303  1.812892e+08  9.926336
#
#
# TOP 5 ASSETS OF COINBASE BY PRICE
#         Exchg    symbol asset         price         vol24  change24
# 220  COINBASE  BTC-USDC   BTC  48749.630166  3.722819e+07  2.110634
# 234  COINBASE  BTC-USDT   BTC  48717.213642  2.221595e+07  2.081364
# 202  COINBASE   BTC-USD   BTC  48709.640000  4.776405e+08  2.046711
# 223  COINBASE   BTC-GBP   BTC  48658.989933  3.489143e+07  2.434739
# 288  COINBASE  WBTC-BTC  WBTC  48639.695417  5.669602e+06  0.004999
# TOP 5 ASSETS OF COINBASE BY 24H VOLUME
#         Exchg    symbol asset         price         vol24   change24
# 200  COINBASE   SOL-USD   SOL    158.978000  6.175064e+08  14.450060
# 201  COINBASE   ETH-USD   ETH   3514.495000  5.971086e+08   0.233722
# 202  COINBASE   BTC-USD   BTC  48709.640000  4.776405e+08   2.046711
# 203  COINBASE   ADA-USD   ADA      2.400700  1.579079e+08   0.338544
# 204  COINBASE  SHIB-USD  SHIB      0.000008  1.140238e+08  -8.258427
#
#
# TOP 5 ASSETS OF KRAKEN BY PRICE
#       Exchg    symbol asset         price         vol24  change24
# 301  KRAKEN   XBT-USD   XBT  48724.550000  9.971976e+07  1.563223
# 347  KRAKEN  XBT-USDC   XBT  48721.083096  2.580070e+06  1.632184
# 320  KRAKEN  XBT-USDT   XBT  48702.072298  1.015273e+07  1.525771
# 339  KRAKEN   XBT-GBP   XBT  48674.723441  3.436115e+06  2.021636
# 302  KRAKEN   XBT-EUR   XBT  48656.423932  8.971207e+07  2.089683
# TOP 5 ASSETS OF KRAKEN BY 24H VOLUME
#       Exchg    symbol asset         price         vol24   change24
# 300  KRAKEN   ETH-USD   ETH   3517.505000  1.525853e+08  -0.529519
# 301  KRAKEN   XBT-USD   XBT  48724.550000  9.971976e+07   1.563223
# 302  KRAKEN   XBT-EUR   XBT  48656.423932  8.971207e+07   2.089683
# 303  KRAKEN  USDT-USD  USDT      1.000050  8.178260e+07  -0.014997
# 304  KRAKEN   SOL-USD   SOL    158.985000  6.830484e+07  10.321976
#
#
# TOP 5 ASSETS OF BITFINEX BY PRICE
#         Exchg   symbol asset         price         vol24  change24
# 460  BITFINEX  BTC-XCH   BTC  9.815509e+06  9.815509e+05  0.293135
# 400  BITFINEX  BTC-USD   BTC  4.875550e+04  1.393155e+08  1.739285
# 424  BITFINEX  BTC-JPY   BTC  4.870890e+04  6.734283e+06  1.754629
# 421  BITFINEX  BTC-GBP   BTC  4.869359e+04  8.065195e+06  1.989020
# 404  BITFINEX  BTC-UST   BTC  4.864904e+04  4.511151e+07  1.723454
# TOP 5 ASSETS OF BITFINEX BY 24H VOLUME
#         Exchg   symbol asset         price         vol24   change24
# 400  BITFINEX  BTC-USD   BTC  48755.500000  1.393155e+08   1.739285
# 401  BITFINEX  ETH-USD   ETH   3517.350000  8.149888e+07  -0.299045
# 402  BITFINEX  SOL-USD   SOL    158.885000  6.474003e+07  11.772775
# 403  BITFINEX  ETH-BTC   ETH   3515.975446  5.286069e+07  -1.961943
# 404  BITFINEX  BTC-UST   BTC  48649.040357  4.511151e+07   1.723454
#
#
# TOP 5 ASSETS OF POLONIEX BY PRICE
#         Exchg     symbol asset         price         vol24  change24
# 506  POLONIEX   BTC-USDC   BTC  48713.342854  3.996062e+06  1.544915
# 502  POLONIEX   BTC-USDT   BTC  48705.298729  2.553277e+07  1.526363
# 584  POLONIEX   YFI-USDT   YFI  34034.719313  4.107913e+04 -1.266757
# 551  POLONIEX  BULL-USDT  BULL   9834.535408  1.140399e+05  6.292120
# 569  POLONIEX    ETH-TRX   ETH   3516.101389  5.995721e+04  6.488370
# TOP 5 ASSETS OF POLONIEX BY 24H VOLUME
#         Exchg     symbol asset         price         vol24  change24
# 500  POLONIEX    ETH-BTC   ETH   3515.001973  2.961507e+07 -2.094404
# 501  POLONIEX   TRX-USDT   TRX      0.107668  2.895908e+07 -6.927301
# 502  POLONIEX   BTC-USDT   BTC  48705.298729  2.553277e+07  1.526363
# 503  POLONIEX   ETH-USDT   ETH   3515.241197  2.182963e+07 -0.569848
# 504  POLONIEX  GALA-USDT  GALA      0.108874  6.840234e+06  3.174721
#
#
# TOP 5 ASSETS OF BITTREX BY PRICE
#        Exchg    symbol asset         price         vol24  change24
# 602  BITTREX  BTC-USDT   BTC  48716.345860  6.032368e+06  1.525274
# 601  BITTREX   BTC-USD   BTC  48715.575000  7.858847e+06  1.544007
# 613  BITTREX   BTC-EUR   BTC  48630.780386  1.935772e+06  2.082766
# 607  BITTREX  ETH-USDT   ETH   3515.960853  2.617641e+06 -0.606876
# 604  BITTREX   ETH-USD   ETH   3515.828000  4.945128e+06 -0.557089
# TOP 5 ASSETS OF BITTREX BY 24H VOLUME
#        Exchg      symbol  asset         price         vol24  change24
# 600  BITTREX  JASMY-USDT  JASMY      0.023837  8.540268e+06 -1.426799
# 601  BITTREX     BTC-USD    BTC  48715.575000  7.858847e+06  1.544007
# 602  BITTREX    BTC-USDT    BTC  48716.345860  6.032368e+06  1.525274
# 603  BITTREX     ETH-BTC    ETH   3514.925742  5.244240e+06 -2.074260
# 604  BITTREX     ETH-USD    ETH   3515.828000  4.945128e+06 -0.557089
